# %%
import matplotlib.pyplot as plt
import numpy as np
import math
import random
# %matplotlib inline

# %%
list = [1, 2, 3, 4, 5, 6, 7, 8]
list
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
plt.plot(list)
